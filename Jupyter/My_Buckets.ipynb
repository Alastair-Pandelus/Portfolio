# %%
from Py_FundSelection import FundSelection
from Py_Portfolio import Portfolio
from functools import reduce
import pandas as pd

EQUITY_PORTFOLIO_YEARS = 6
LOW_CORRELATION_PORTFOLIO_YEARS = 6

# Man Dynamic Fund lacks back data 
#LOW_VOLATILITY_PORTFOLIO_YEARS = 3

N_PORTFOLIOS = 1000000
RISK_FREE_RATE = 0.0375 

# Low Vol
low_vol_abridged_fund_selection = [
    FundSelection('JupiterMerian Glb Eq AbsRt I £ H Acc', 0.4),
    FundSelection('Prem Miton Tellworth UK Sel Fd - Cl AAcc', 0.2),
    FundSelection('JPM Europe Equity Absolute Alpha C (perf) (dist) - GBP (hedged)', 0.4),
    #FundSelection('Man High Yield Opports Profl Acc C'), 
]

# Benchmark 4PHUXACHE
# benchmark = [
#     FundSelection('Ranmore Global Equity Investor GBP', 0.25),
#     FundSelection('L&G Global 100 Index I Acc', 0.13, proxy_funds=[FundSelection('Fidelity Global Technology W-Acc-GBP', 1.0)]),
#     FundSelection('MFS Meridian Contrarian Value W1 GBP', 0.06),
#     FundSelection('FAST - Global Fund Y-PF-ACC-GBP', 0.06),
#     FundSelection('YFS Argonaut Absolute Return I GBP Acc', 0.10),
#     FundSelection('BH Macro GBP Ord', 0.10),
#     FundSelection('WisdomTree Physical Gold GBP Daily Hdgd', 0.10),
#     FundSelection('Winton Trend UCITS I GBP Acc', 0.05),
#     FundSelection('iShares Blmbrg Enh Roll Yld Cmd Swap ETF GBP',0.05),
#     FundSelection('JupiterMerian Glb Eq AbsRt I £ H Acc', 0.05),
#     FundSelection('Prem Miton Tellworth UK Sel Fd - Cl AAcc', 0.05)
# ]

benchmark = [
    FundSelection('Ranmore Global Equity Investor GBP', 0.1343), 
    FundSelection('Ashoka India Equity Investment Ord', 0.0269),
    FundSelection('Invesco S&P 500 QVM ETF GBP', 0.0465), 
    FundSelection('L&G Global 100 Index I Acc', 0.0998, proxy_funds=[FundSelection('Fidelity Global Technology W-Acc-GBP', 1.0)]),
    FundSelection('Orbis OEIC Global Balanced Standard', 0.1325), # ~0.73 Correlated with global tracker
    FundSelection('Winton Trend Enh Glbl Eq UCITSIGBPUnHAcc', 0.06, proxy_funds=[FundSelection('Fidelity Global Technology W-Acc-GBP', 1.0)]),

    FundSelection('Prem Miton Tellworth UK Sel Fd - Cl AAcc', 0.0278),
    FundSelection('Man Dynamic Income I H GBP Cap', 0.1247, proxy_funds=low_vol_abridged_fund_selection),
    FundSelection('JupiterMerian Glb Eq AbsRt I £ H Acc', 0.0584),
    FundSelection('JPM Europe Equity Absolute Alpha C (perf) (dist) - GBP (hedged)', 0.0592),

    FundSelection('YFS Argonaut Absolute Return I GBP Acc', 0.0987),
    FundSelection('iShares Physical Gold ETC GBP', 0.0921),
    FundSelection('iShares Blmbrg Enh Roll Yld Cmd Swap ETF GBP', 0.0392),
]

# Equity
equity_fund_selection = [
    FundSelection('Ranmore Global Equity Investor GBP'), # ~0.59 Correlated with global tracker
    FundSelection('Orbis OEIC Global Balanced Standard'), # ~0.73 Correlated with global tracker
    FundSelection('L&G Global 100 Index I Acc', proxy_funds=[FundSelection('Fidelity Global Technology W-Acc-GBP', 1.0)]),
    FundSelection('Winton Trend Enh Glbl Eq UCITSIGBPUnHAcc', proxy_funds=[FundSelection('Fidelity Global Technology W-Acc-GBP', 1.0)]),
    FundSelection('Invesco S&P 500 QVM ETF GBP'),

    #FundSelection('Artemis Global Income I Acc'),
    #FundSelection('Artemis SmartGARP Glb EM Eq I Acc GBP'),
    #FundSelection('MFS Meridian Contrarian Value W1 GBP'), # ~0.74 Correlated with global tracker
    #FundSelection('FAST - Global Fund Y-PF-ACC-GBP'), # ~0.49 Correlated with global tracker
    #FundSelection('WisdomTree Glb Efficient Cor ETFUSDAcc GBP', proxy_funds=[FundSelection('SPDR MSCI All Cntry Wld ETF GBP', 0.9), FundSelection('Vanguard Glb Bd Idx £ H Acc', 0.6)]),
    #FundSelection('Ashoka India Equity Investment Ord'),
    
    FundSelection('Artemis SmartGARP Glb EM Eq I Acc GBP'),
    #FundSelection('Invesco Em Mkts ex China UK Z Acc'),
    FundSelection('Redwheel Next Gen Em Mkts Eq R GBP Acc'),
    FundSelection('HSBC GIF Frontier Markets BCGBP'),
    #FundSelection('iShares Pacific ex Jpn Eq Idx (UK) D Acc'), # missing price data - check against final choice in FT.com
    #FundSelection('iShares MSCI EM Latin Amer ETF USD Dist GBP'),
]

equity_portfolio = Portfolio(equity_fund_selection, benchmark, EQUITY_PORTFOLIO_YEARS, N_PORTFOLIOS, RISK_FREE_RATE)

# # Only data from 2022, so proxy earlier years with the best Sharpe ratio weghtings from the other funds
# man_dynamic_income = FundSelection('Man Dynamic Income I H GBP Cap', proxy_funds=low_vol_abridged_fund_selection)

# low_vol_full_fund_selection = low_vol_abridged_fund_selection + [
#     man_dynamic_income
# ]

# benchmark = [
#     FundSelection('Ranmore Global Equity Investor GBP', 0.25),
#     FundSelection('L&G Global 100 Index I Acc', 0.13, proxy_funds=[FundSelection('Fidelity Global Technology W-Acc-GBP', 1.0)]),
#     FundSelection('MFS Meridian Contrarian Value W1 GBP', 0.06),
#     FundSelection('FAST - Global Fund Y-PF-ACC-GBP', 0.06),
#     FundSelection('YFS Argonaut Absolute Return I GBP Acc', 0.10),
#     FundSelection('BH Macro GBP Ord', 0.10),
#     FundSelection('WisdomTree Physical Gold GBP Daily Hdgd', 0.10),
#     FundSelection('Winton Trend UCITS I GBP Acc', 0.05),
#     FundSelection('iShares Blmbrg Enh Roll Yld Cmd Swap ETF GBP',0.05),
#     FundSelection('JupiterMerian Glb Eq AbsRt I £ H Acc', 0.05),
#     FundSelection('Prem Miton Tellworth UK Sel Fd - Cl AAcc', 0.05)
# ]

# # Abridged Portfolio excludes Man Dynamic - calculate max Sharpe Ratio and associated weights to backfill proxy fund weights in full portfolio
# low_vol_abridged_portfolio = Portfolio(low_vol_abridged_fund_selection, benchmark, LOW_VOLATILITY_PORTFOLIO_YEARS, N_PORTFOLIOS, RISK_FREE_RATE)

# # Full Portfolio - 1st 3 years of Man Dynamic Income fund backfilled with the proxy fund weights from the abridged portfolio
# low_vol_portfolio = Portfolio(low_vol_full_fund_selection, benchmark, LOW_VOLATILITY_PORTFOLIO_YEARS, N_PORTFOLIOS, RISK_FREE_RATE)

# # Low Correlation
# # iShares Physical Gold ETC GBP => WisdomTree Physical Gold GBP Daily Hdgd at some point to currency hedge
# low_correlaton_fund_selection = [
#     FundSelection('iShares Physical Gold ETC GBP'),
#     FundSelection('iShares Blmbrg Enh Roll Yld Cmd Swap ETF GBP'),
#     FundSelection('YFS Argonaut Absolute Return I GBP Acc'),
# ]

# low_correlaton_portfolio = Portfolio(low_correlaton_fund_selection, benchmark, LOW_CORRELATION_PORTFOLIO_YEARS, N_PORTFOLIOS, RISK_FREE_RATE)

# %%
equity_portfolio.plot_returns_tear_sheet()
#low_vol_portfolio.plot_returns_tear_sheet()
#low_correlaton_portfolio.plot_returns_tear_sheet()
# Out:
# C:\Users\Pandelus\AppData\Roaming\Python\Python313\site-packages\pyfolio\plotting.py:670: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.601%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   perf_stats.loc[stat, column] = str(np.round(value * 100, 3)) + "%"
# c:\Users\Pandelus\source\repos\Portfolio\Jupyter\Portfolio.py:692: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y=max_sharpe_portf['AverageReturns'][asset_index],
# C:\Users\Pandelus\AppData\Roaming\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\Pandelus\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
equity_results = equity_portfolio.export('Equity')
#low_vol_results = low_vol_portfolio.export('LowVol')
#low_correlation_results = low_correlaton_portfolio.export('LowCorr')

#combined_results = pd.concat([equity_results, low_vol_results, low_correlation_results])
combined_results = pd.concat([equity_results])

# xlswriter needs to be installed
combined_results.to_excel('EmergingMarkets.xlsx', index=True)
# Out:
# c:\Users\Pandelus\source\repos\Portfolio\Jupyter\Portfolio.py:734: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.08746346106516802' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   portfolio.loc[name, 'YTD'] = ytd
# c:\Users\Pandelus\source\repos\Portfolio\Jupyter\Portfolio.py:737: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.11507301428236079' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   portfolio.loc[name, 'Weight'] = name_weight[name]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 9
#       6 combined_results = pd.concat([equity_results])
#       8 # xlswriter needs to be installed
# ----> 9 combined_results.to_excel('EmergingMarkets.xlsx', index=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:2436, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2423 from pandas.io.formats.excel import ExcelFormatter
#    2425 formatter = ExcelFormatter(
#    2426     df,
#    2427     na_rep=na_rep,
#    (...)   2434     inf_rep=inf_rep,
#    2435 )
# -> 2436 formatter.write(
#    2437     excel_writer,
#    2438     sheet_name=sheet_name,
#    2439     startrow=startrow,
#    2440     startcol=startcol,
#    2441     freeze_panes=freeze_panes,
#    2442     engine=engine,
#    2443     storage_options=storage_options,
#    2444     engine_kwargs=engine_kwargs,
#    2445 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\excel\_xlsxwriter.py:204, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     201 if mode == "a":
#     202     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 204 super().__init__(
#     205     path,
#     206     engine=engine,
#     207     date_format=date_format,
#     208     datetime_format=datetime_format,
#     209     mode=mode,
#     210     storage_options=storage_options,
#     211     if_sheet_exists=if_sheet_exists,
#     212     engine_kwargs=engine_kwargs,
#     213 )
#     215 try:
#     216     self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'EmergingMarkets.xlsx'
